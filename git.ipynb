# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd gdrive/My Drive/
# %cd VIP-IPA work folder
# Out:
# [Errno 2] No such file or directory: 'gdrive/My Drive/'
# /content/gdrive/My Drive/VIP-IPA work folder
# [Errno 2] No such file or directory: 'VIP-IPA work folder'
# /content/gdrive/My Drive/VIP-IPA work folder

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/gdrive/My Drive/VIP-IPA work folder/.git/

# %%
# !git remote set-url origin https://GKandula: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@github.com/GKandula/VIP-IPA-Personal.git
# !git remote -v
# Out:
# origin	https://GKandula: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@github.com/GKandula/VIP-IPA-Personal.git (fetch)
# origin	https://GKandula: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@github.com/GKandula/VIP-IPA-Personal.git (push)

# %%
# !git config --global user.email 'gunvanthreddy@gmail.com'
# !git config --global user.name 'GKandula'

# %%
# !git add .
# !git commit -m 'First commit'
# Out:
# [master (root-commit) 3ffaba2] First commit
#  2 files changed, 2 insertions(+)
#  create mode 100644 VIP IPA Test.ipynb
#  create mode 100644 git.ipynb

# %%
# !git push origin main
# Out:
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/GKandula/VIP-IPA-Personal.git'
