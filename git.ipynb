# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/My Drive/
# %cd VIP-IPA work folder
# Out:
# /content/gdrive/My Drive
# /content/gdrive/My Drive/VIP-IPA work folder

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/gdrive/My Drive/VIP-IPA work folder/.git/

# %%
# !git remote add origin https://GKandula@github.com/GKandula/VIP-IPA-Personal.git
# !git remote -v
# Out:
# error: remote origin already exists.
# origin	https://GKandula:Gunvanth2005#@github.com/GKandula/VIP-IPA-Personal.git (fetch)
# origin	https://GKandula:Gunvanth2005#@github.com/GKandula/VIP-IPA-Personal.git (push)

# %%
# !git config --global user.email 'g'
# !git config --global user.name '{user_name}'
